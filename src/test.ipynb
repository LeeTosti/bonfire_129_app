# %%
import requests
import pandas as pd

# %%
card_requests = requests.get('https://api.scryfall.com/bulk-data').json()['data'][0]['download_uri']

cards = requests.get(card_requests).json()

pd.DataFrame.from_dict(cards)
# Out:
#       object                                    id  \
# 0       card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1       card  7050735c-b232-47a6-a342-01795bfd0d46
# 2       card  e718b21b-46d1-4844-985c-52745657b1ac
# 3       card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4       card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
# ...      ...                                   ...
# 29970   card  d6695fa8-881c-407c-91d9-3ac770372d35
# 29971   card  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 29972   card  22a6a5f1-1405-4efb-af3e-e1f58d664e99
# 29973   card  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 29974   card  1ecc983e-bbe3-4bc1-97e9-e40ead987ef0
#
#                                   oracle_id    multiverse_ids   mtgo_id  \
# 0      0004ebd0-dfd6-4276-b4a6-de0003e94237           [15862]   15870.0
# 1      0006faf6-7a61-426c-9034-579f2cfcfa83          [370780]   49283.0
# 2      0007c283-5b7a-4c00-9ca1-b455c8dff8c3          [470580]   77122.0
# ...

# %%
df = pd.DataFrame.from_dict(requests.get(requests.get('https://api.scryfall.com/bulk-data').json()['data'][0]['download_uri']).json())

df
# Out:
#       object                                    id  \
# 0       card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1       card  7050735c-b232-47a6-a342-01795bfd0d46
# 2       card  e718b21b-46d1-4844-985c-52745657b1ac
# 3       card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4       card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
# ...      ...                                   ...
# 29970   card  d6695fa8-881c-407c-91d9-3ac770372d35
# 29971   card  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 29972   card  22a6a5f1-1405-4efb-af3e-e1f58d664e99
# 29973   card  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 29974   card  1ecc983e-bbe3-4bc1-97e9-e40ead987ef0
#
#                                   oracle_id    multiverse_ids   mtgo_id  \
# 0      0004ebd0-dfd6-4276-b4a6-de0003e94237           [15862]   15870.0
# 1      0006faf6-7a61-426c-9034-579f2cfcfa83          [370780]   49283.0
# 2      0007c283-5b7a-4c00-9ca1-b455c8dff8c3          [470580]   77122.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29975 entries, 0 to 29974
# Data columns (total 80 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   object               29975 non-null  object
#  1   id                   29975 non-null  object
#  2   oracle_id            29975 non-null  object
#  3   multiverse_ids       29975 non-null  object
#  4   mtgo_id              21533 non-null  float64
#  5   mtgo_foil_id         11930 non-null  float64
#  6   tcgplayer_id         26128 non-null  float64
#  7   cardmarket_id        25583 non-null  float64
#  8   name                 29975 non-null  object
#  9   lang                 29975 non-null  object
#  10  released_at          29975 non-null  object
#  11  uri                  29975 non-null  object
#  12  scryfall_uri         29975 non-null  object
#  13  layout               29975 non-null  object
#  14  highres_image        29975 non-null  bool
# ...

# %%
con_str = 'mongodb+srv://ophelia44:cancerrising@bonfire129.sbdehdn.mongodb.net/?retryWrites=true&w=majority'

import pymongo
import certifi
client = pymongo.MongoClient(con_str, tlsCAFile=certifi.where())

# %%
# Create databases
db = client.db

# Create a collection from the database
cards = db.cards

# %%
# Set the dataframe index to the id column:
df.set_index('id', inplace=True)

# %%
df['oracle_text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 29975 entries, 86bf43b1-8d4e-4759-bb2d-0b2e03ba7012 to 1ecc983e-bbe3-4bc1-97e9-e40ead987ef0
# Series name: oracle_text
# Non-Null Count  Dtype
# --------------  -----
# 27995 non-null  object
# dtypes: object(1)
# memory usage: 1.5+ MB

# %%
# Try to insert many:
cards.insert_many([df.to_dict()])
# Out:
# ---------------------------------------------------------------------------
# DocumentTooLarge                          Traceback (most recent call last)
# /Users/lisatosti/Documents/GitHub/bonfire_129_app/src/test.ipynb Cell 9 line 2
#       <a href='vscode-notebook-cell:/Users/lisatosti/Documents/GitHub/bonfire_129_app/src/test.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # Try to insert many:
# ----> <a href='vscode-notebook-cell:/Users/lisatosti/Documents/GitHub/bonfire_129_app/src/test.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> cards.insert_many([df.to_dict()])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# ...

# %%
for i in df.index[:3]:
    print(cards.insert_one(df.loc[i].to_dict()))
